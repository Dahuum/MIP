# %%
"""
PYTORCH_DEEP_LEARNING.py - LSTM Neural Network using PyTorch
==============================================================
Pure Deep Learning - NO Random Forest, NO Traditional ML

Uses PyTorch (stable on macOS, uses all CPU cores)
"""
# Out:
# '\nPYTORCH_DEEP_LEARNING.py - LSTM Neural Network using PyTorch\n==============================================================\nPure Deep Learning - NO Random Forest, NO Traditional ML\n\nUses PyTorch (stable on macOS, uses all CPU cores)\n'

# %%
import os
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# %%
# PyTorch imports
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import recall_score, precision_score, f1_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 # PyTorch imports
# ----> 2 import torch
#       3 import torch.nn as nn
#       4 import torch.optim as optim
#
# ModuleNotFoundError: No module named 'torch'

# %%
# Use all CPU cores
torch.set_num_threads(os.cpu_count())
device = torch.device('cpu')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Use all CPU cores
# ----> 2 torch.set_num_threads(os.cpu_count())
#       3 device = torch.device('cpu')
#
# NameError: name 'torch' is not defined

# %%
print("=" * 80)
print("🧠 PyTorch LSTM DEEP LEARNING MODEL")
print("   Pure Neural Network - No Random Forest")
print("=" * 80)
print(f"   PyTorch Version: {torch.__version__}")
print(f"   CPU Threads: {torch.get_num_threads()}")
print(f"   Device: {device}")
# Out:
# ================================================================================
# 🧠 PyTorch LSTM DEEP LEARNING MODEL
#    Pure Neural Network - No Random Forest
# ================================================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       3 print("   Pure Neural Network - No Random Forest")
#       4 print("=" * 80)
# ----> 5 print(f"   PyTorch Version: {torch.__version__}")
#       6 print(f"   CPU Threads: {torch.get_num_threads()}")
#       7 print(f"   Device: {device}")
#
# NameError: name 'torch' is not defined

# %%
# =============================================================================
# CONFIGURATION
# =============================================================================
CONFIG = {
    "SEQUENCE_LENGTH": 30,
    "PREDICTION_HOURS": 24,
    "HIDDEN_SIZE": 64,
    "NUM_LAYERS": 2,
    "DROPOUT": 0.2,
    "EPOCHS": 30,
    "BATCH_SIZE": 64,
    "LEARNING_RATE": 0.001,
    "SKIP_ROWS": 15609,
    "SAMPLE_RATE": 5,
    "DUST_WARNING": 15.0,
}

# %%
print("\n⚙️  CONFIG:", CONFIG)
# Out:
# ⚙️  CONFIG: {'SEQUENCE_LENGTH': 30, 'PREDICTION_HOURS': 24, 'HIDDEN_SIZE': 64, 'NUM_LAYERS': 2, 'DROPOUT': 0.2, 'EPOCHS': 30, 'BATCH_SIZE': 64, 'LEARNING_RATE': 0.001, 'SKIP_ROWS': 15609, 'SAMPLE_RATE': 5, 'DUST_WARNING': 15.0}

# %%
# =============================================================================
# STEP 1: LOAD DATA
# =============================================================================
print("\n" + "=" * 80)
print("📊 STEP 1: Loading data...")
print("=" * 80)
# Out:
# ================================================================================
# 📊 STEP 1: Loading data...
# ================================================================================

# %%
failures_df = pd.read_csv("failure_events_with_dust.csv")
failures_df["timestamp"] = pd.to_datetime(failures_df["timestamp"])
print(f"   ✓ {len(failures_df)} failures loaded")
# Out:
#    ✓ 22 failures loaded

# %%
df = pd.read_csv("Dataframemin.csv", skiprows=range(1, CONFIG["SKIP_ROWS"] + 1))
df["Date"] = pd.to_datetime(df["Date"], format="%d/%m/%Y %H:%M")
df.columns = ["Date", "Motor_Current", "Temp_Opposite", "Temp_Motor", 
              "Vib_Opposite", "Vib_Motor", "Valve_Opening"]
df = df.sort_values("Date").reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = pd.read_csv("Dataframemin.csv", skiprows=range(1, CONFIG["SKIP_ROWS"] + 1))
#       2 df["Date"] = pd.to_datetime(df["Date"], format="%d/%m/%Y %H:%M")
#       3 df.columns = ["Date", "Motor_Current", "Temp_Opposite", "Temp_Motor",
#       4               "Vib_Opposite", "Vib_Motor", "Valve_Opening"]
#
# File ~/Desktop/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Desktop/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Desktop/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Desktop/venv/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Dataframemin.csv'

# %%
# Sample for speed
df = df.iloc[::CONFIG["SAMPLE_RATE"]].reset_index(drop=True)
print(f"   ✓ {len(df):,} records (sampled)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Sample for speed
# ----> 2 df = df.iloc[::CONFIG["SAMPLE_RATE"]].reset_index(drop=True)
#       3 print(f"   ✓ {len(df):,} records (sampled)")
#
# NameError: name 'df' is not defined

# %%
# Clean
sensor_cols = ["Motor_Current", "Temp_Opposite", "Temp_Motor", 
               "Vib_Opposite", "Vib_Motor", "Valve_Opening"]
for col in sensor_cols:
    df[col] = pd.to_numeric(df[col], errors="coerce")
df[sensor_cols] = df[sensor_cols].ffill().bfill()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       2 sensor_cols = ["Motor_Current", "Temp_Opposite", "Temp_Motor",
#       3                "Vib_Opposite", "Vib_Motor", "Valve_Opening"]
#       4 for col in sensor_cols:
# ----> 5     df[col] = pd.to_numeric(df[col], errors="coerce")
#       6 df[sensor_cols] = df[sensor_cols].ffill().bfill()
#
# NameError: name 'df' is not defined

# %%
# =============================================================================
# STEP 2: FEATURES
# =============================================================================
print("\n" + "=" * 80)
print("🔧 STEP 2: Creating features...")
print("=" * 80)
# Out:
# ================================================================================
# 🔧 STEP 2: Creating features...
# ================================================================================

# %%
feature_cols = sensor_cols.copy()

# %%
for col in sensor_cols:
    df[f"{col}_diff"] = df[col].diff().fillna(0)
    feature_cols.append(f"{col}_diff")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 for col in sensor_cols:
# ----> 2     df[f"{col}_diff"] = df[col].diff().fillna(0)
#       3     feature_cols.append(f"{col}_diff")
#
# NameError: name 'df' is not defined

# %%
df["Vib_Total"] = df["Vib_Motor"] + df["Vib_Opposite"]
df["Temp_Diff"] = df["Temp_Motor"] - df["Temp_Opposite"]
feature_cols.extend(["Vib_Total", "Temp_Diff"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df["Vib_Total"] = df["Vib_Motor"] + df["Vib_Opposite"]
#       2 df["Temp_Diff"] = df["Temp_Motor"] - df["Temp_Opposite"]
#       3 feature_cols.extend(["Vib_Total", "Temp_Diff"])
#
# NameError: name 'df' is not defined

# %%
print(f"   ✓ {len(feature_cols)} features")
# Out:
#    ✓ 6 features

# %%
# =============================================================================
# STEP 3: LABELS
# =============================================================================
print("\n" + "=" * 80)
print("🏷️  STEP 3: Creating labels...")
print("=" * 80)
# Out:
# ================================================================================
# 🏷️  STEP 3: Creating labels...
# ================================================================================

# %%
df["label"] = 0
for _, f in failures_df.iterrows():
    start = f["timestamp"] - timedelta(hours=CONFIG["PREDICTION_HOURS"])
    mask = (df["Date"] >= start) & (df["Date"] < f["timestamp"])
    df.loc[mask, "label"] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df["label"] = 0
#       2 for _, f in failures_df.iterrows():
#       3     start = f["timestamp"] - timedelta(hours=CONFIG["PREDICTION_HOURS"])
#
# NameError: name 'df' is not defined

# %%
pos = (df["label"] == 1).sum()
neg = (df["label"] == 0).sum()
print(f"   ✓ Positive: {pos:,}, Negative: {neg:,}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 pos = (df["label"] == 1).sum()
#       2 neg = (df["label"] == 0).sum()
#       3 print(f"   ✓ Positive: {pos:,}, Negative: {neg:,}")
#
# NameError: name 'df' is not defined

# %%
# =============================================================================
# STEP 4: PREPARE DATA
# =============================================================================
print("\n" + "=" * 80)
print("🔄 STEP 4: Preparing sequences...")
print("=" * 80)
# Out:
# ================================================================================
# 🔄 STEP 4: Preparing sequences...
# ================================================================================

# %%
scaler = MinMaxScaler()
df[feature_cols] = scaler.fit_transform(df[feature_cols])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 scaler = MinMaxScaler()
#       2 df[feature_cols] = scaler.fit_transform(df[feature_cols])
#
# NameError: name 'MinMaxScaler' is not defined

# %%
split = int(len(df) * 0.7)
train_df = df[:split]
test_df = df[split:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 split = int(len(df) * 0.7)
#       2 train_df = df[:split]
#       3 test_df = df[split:]
#
# NameError: name 'df' is not defined

# %%
def make_sequences(data, seq_len):
    X, y = [], []
    vals = data[feature_cols].values
    labs = data["label"].values
    for i in range(seq_len, len(data)):
        X.append(vals[i-seq_len:i])
        y.append(labs[i])
    return np.array(X), np.array(y)

# %%
seq_len = CONFIG["SEQUENCE_LENGTH"]
X_train, y_train = make_sequences(train_df, seq_len)
X_test, y_test = make_sequences(test_df, seq_len)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 seq_len = CONFIG["SEQUENCE_LENGTH"]
# ----> 2 X_train, y_train = make_sequences(train_df, seq_len)
#       3 X_test, y_test = make_sequences(test_df, seq_len)
#
# NameError: name 'train_df' is not defined

# %%
print(f"   ✓ Train: {X_train.shape}, Test: {X_test.shape}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(f"   ✓ Train: {X_train.shape}, Test: {X_test.shape}")
#
# NameError: name 'X_train' is not defined

# %%
# Convert to PyTorch tensors
X_train_t = torch.FloatTensor(X_train)
y_train_t = torch.FloatTensor(y_train)
X_test_t = torch.FloatTensor(X_test)
y_test_t = torch.FloatTensor(y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # Convert to PyTorch tensors
# ----> 2 X_train_t = torch.FloatTensor(X_train)
#       3 y_train_t = torch.FloatTensor(y_train)
#       4 X_test_t = torch.FloatTensor(X_test)
#
# NameError: name 'torch' is not defined

# %%
train_dataset = TensorDataset(X_train_t, y_train_t)
train_loader = DataLoader(train_dataset, batch_size=CONFIG["BATCH_SIZE"], shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 train_dataset = TensorDataset(X_train_t, y_train_t)
#       2 train_loader = DataLoader(train_dataset, batch_size=CONFIG["BATCH_SIZE"], shuffle=True)
#
# NameError: name 'TensorDataset' is not defined

# %%
# Class weights - cap at 10x to prevent gradient explosion
raw_weight = neg / pos if pos > 0 else 1.0
pos_weight = torch.tensor([min(raw_weight, 10.0)])  # Cap weight to prevent instability
print(f"   ✓ Positive class weight: {pos_weight.item():.2f} (raw: {raw_weight:.2f})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Class weights - cap at 10x to prevent gradient explosion
# ----> 2 raw_weight = neg / pos if pos > 0 else 1.0
#       3 pos_weight = torch.tensor([min(raw_weight, 10.0)])  # Cap weight to prevent instability
#       4 print(f"   ✓ Positive class weight: {pos_weight.item():.2f} (raw: {raw_weight:.2f})")
#
# NameError: name 'pos' is not defined

# %%
# =============================================================================
# STEP 5: DEFINE LSTM MODEL
# =============================================================================
print("\n" + "=" * 80)
print("🧠 STEP 5: Building LSTM Neural Network...")
print("=" * 80)
# Out:
# ================================================================================
# 🧠 STEP 5: Building LSTM Neural Network...
# ================================================================================

# %%
class LSTMModel(nn.Module):
    """
    LSTM Deep Learning Model for Predictive Maintenance
    
    Architecture:
    - LSTM layers (learn temporal patterns)
    - Dropout (prevent overfitting)
    - Dense output (binary classification)
    """
    def __init__(self, input_size, hidden_size, num_layers, dropout):
        super(LSTMModel, self).__init__()
        
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0
        )
        
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_size, 1)
        # NOTE: No sigmoid here - BCEWithLogitsLoss applies it internally
    
    def forward(self, x):
        # LSTM forward pass
        lstm_out, _ = self.lstm(x)
        # Take last timestep output
        last_out = lstm_out[:, -1, :]
        # Dropout + Dense (raw logits)
        out = self.dropout(last_out)
        out = self.fc(out)
        return out.squeeze()  # Returns raw logits, not probabilities
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 class LSTMModel(nn.Module):
#       2     """
#       3     LSTM Deep Learning Model for Predictive Maintenance
#       4
#    (...)      8     - Dense output (binary classification)
#       9     """
#      10     def __init__(self, input_size, hidden_size, num_layers, dropout):
#
# NameError: name 'nn' is not defined

# %%
model = LSTMModel(
    input_size=len(feature_cols),
    hidden_size=CONFIG["HIDDEN_SIZE"],
    num_layers=CONFIG["NUM_LAYERS"],
    dropout=CONFIG["DROPOUT"]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 model = LSTMModel(
#       2     input_size=len(feature_cols),
#       3     hidden_size=CONFIG["HIDDEN_SIZE"],
#       4     num_layers=CONFIG["NUM_LAYERS"],
#       5     dropout=CONFIG["DROPOUT"]
#       6 )
#
# NameError: name 'LSTMModel' is not defined

# %%
print(f"\n   📐 MODEL ARCHITECTURE:")
print(model)
total_params = sum(p.numel() for p in model.parameters())
print(f"\n   ✓ Total parameters: {total_params:,}")
# Out:
#    📐 MODEL ARCHITECTURE:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 print(f"\n   📐 MODEL ARCHITECTURE:")
# ----> 2 print(model)
#       3 total_params = sum(p.numel() for p in model.parameters())
#       4 print(f"\n   ✓ Total parameters: {total_params:,}")
#
# NameError: name 'model' is not defined

# %%
# =============================================================================
# STEP 6: TRAIN (Self-correction via Backpropagation)
# =============================================================================
print("\n" + "=" * 80)
print("🎓 STEP 6: Training LSTM (Self-correcting via Backpropagation)...")
print("=" * 80)
# Out:
# ================================================================================
# 🎓 STEP 6: Training LSTM (Self-correcting via Backpropagation)...
# ================================================================================

# %%
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
optimizer = optim.Adam(model.parameters(), lr=CONFIG["LEARNING_RATE"])
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
#       2 optimizer = optim.Adam(model.parameters(), lr=CONFIG["LEARNING_RATE"])
#       3 scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)
#
# NameError: name 'nn' is not defined

# %%
print("\n   Epoch  |  Loss   | Train Acc | Train Rec |  Progress")
print("   " + "-" * 55)
# Out:
#    Epoch  |  Loss   | Train Acc | Train Rec |  Progress
#    -------------------------------------------------------

# %%
for epoch in range(CONFIG["EPOCHS"]):
    model.train()
    total_loss = 0
    correct = 0
    total = 0
    true_pos = 0
    actual_pos = 0
    
    for X_batch, y_batch in train_loader:
        # Forward pass
        optimizer.zero_grad()
        outputs = model(X_batch)  # Raw logits
        
        # Calculate loss
        loss = criterion(outputs, y_batch)
        
        # BACKPROPAGATION - This is the self-correction!
        loss.backward()  # Compute gradients
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Prevent exploding gradients
        optimizer.step()  # Update weights
        
        total_loss += loss.item()
        probs = torch.sigmoid(outputs)  # Convert logits to probabilities
        preds = (probs > 0.5).float()
        correct += (preds == y_batch).sum().item()
        total += len(y_batch)
        
        # Track recall
        true_pos += ((preds == 1) & (y_batch == 1)).sum().item()
        actual_pos += (y_batch == 1).sum().item()
    
    acc = correct / total
    avg_loss = total_loss / len(train_loader)
    train_recall = true_pos / actual_pos if actual_pos > 0 else 0
    
    # Update learning rate based on loss
    scheduler.step(avg_loss)
    
    bar = "█" * (epoch + 1) + "░" * (CONFIG["EPOCHS"] - epoch - 1)
    print(f"   {epoch+1:3d}    | {avg_loss:.4f} |  {acc:.2%}   |  {train_recall:.2%}   | {bar[:20]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 for epoch in range(CONFIG["EPOCHS"]):
# ----> 2     model.train()
#       3     total_loss = 0
#       4     correct = 0
#
# NameError: name 'model' is not defined

# %%
print("\n   ✓ Training complete!")
# Out:
#    ✓ Training complete!

# %%
# =============================================================================
# STEP 7: EVALUATE
# =============================================================================
print("\n" + "=" * 80)
print("📊 STEP 7: Evaluating model...")
print("=" * 80)
# Out:
# ================================================================================
# 📊 STEP 7: Evaluating model...
# ================================================================================

# %%
model.eval()
with torch.no_grad():
    logits = model(X_test_t)
    y_pred_proba = torch.sigmoid(logits).numpy()  # Convert logits to probabilities
    y_pred = (y_pred_proba > 0.5).astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 model.eval()
#       2 with torch.no_grad():
#       3     logits = model(X_test_t)
#
# NameError: name 'model' is not defined

# %%
recall = recall_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, zero_division=0)
f1 = f1_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 recall = recall_score(y_test, y_pred)
#       2 precision = precision_score(y_test, y_pred, zero_division=0)
#       3 f1 = f1_score(y_test, y_pred)
#
# NameError: name 'recall_score' is not defined

# %%
print(f"\n   🎯 METRICS:")
print(f"      Recall:    {recall:.2%}")
print(f"      Precision: {precision:.2%}")
print(f"      F1-Score:  {f1:.2%}")
# Out:
#    🎯 METRICS:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 print(f"\n   🎯 METRICS:")
# ----> 2 print(f"      Recall:    {recall:.2%}")
#       3 print(f"      Precision: {precision:.2%}")
#       4 print(f"      F1-Score:  {f1:.2%}")
#
# NameError: name 'recall' is not defined

# %%
# =============================================================================
# STEP 8: FAILURE-BASED EVALUATION
# =============================================================================
print("\n" + "=" * 80)
print("🎯 STEP 8: Checking each failure...")
print("=" * 80)
# Out:
# ================================================================================
# 🎯 STEP 8: Checking each failure...
# ================================================================================

# %%
test_start = df.iloc[split]["Date"]
test_failures = failures_df[failures_df["timestamp"] >= test_start]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 test_start = df.iloc[split]["Date"]
#       2 test_failures = failures_df[failures_df["timestamp"] >= test_start]
#
# NameError: name 'df' is not defined

# %%
print(f"\n   Testing {len(test_failures)} failures:\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 print(f"\n   Testing {len(test_failures)} failures:\n")
#
# NameError: name 'test_failures' is not defined

# %%
caught = 0
dust_caught = 0
total_dust = 0

# %%
for _, failure in test_failures.iterrows():
    f_time = failure["timestamp"]
    f_type = failure["failure_type"]
    dust = failure["Dust_Quantity_kg"]
    is_dust = dust >= CONFIG["DUST_WARNING"]
    
    if is_dust:
        total_dust += 1
    
    window_start = f_time - timedelta(hours=CONFIG["PREDICTION_HOURS"])
    test_dates = test_df.iloc[seq_len:]["Date"].values
    mask = (test_dates >= np.datetime64(window_start)) & (test_dates <= np.datetime64(f_time))
    
    if mask.sum() > 0:
        preds = y_pred[mask]
        probs = y_pred_proba[mask]
        
        detected = preds.sum() > 0
        max_prob = probs.max()
        
        if detected:
            caught += 1
            if is_dust:
                dust_caught += 1
            status = "✓ CAUGHT"
        else:
            status = "✗ MISSED"
        
        dust_icon = "🌫️" if is_dust else "  "
        print(f"   {dust_icon} {status} {f_time} ({f_type}) prob={max_prob:.1%}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 for _, failure in test_failures.iterrows():
#       2     f_time = failure["timestamp"]
#       3     f_type = failure["failure_type"]
#
# NameError: name 'test_failures' is not defined

# %%
failure_recall = caught / len(test_failures) if len(test_failures) > 0 else 0
dust_recall = dust_caught / total_dust if total_dust > 0 else 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 failure_recall = caught / len(test_failures) if len(test_failures) > 0 else 0
#       2 dust_recall = dust_caught / total_dust if total_dust > 0 else 0
#
# NameError: name 'test_failures' is not defined

# %%
print(f"\n   📊 RESULTS:")
print(f"      Failures: {caught}/{len(test_failures)} caught ({failure_recall:.0%})")
print(f"      Dust failures: {dust_caught}/{total_dust} ({dust_recall:.0%})")
# Out:
#    📊 RESULTS:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 print(f"\n   📊 RESULTS:")
# ----> 2 print(f"      Failures: {caught}/{len(test_failures)} caught ({failure_recall:.0%})")
#       3 print(f"      Dust failures: {dust_caught}/{total_dust} ({dust_recall:.0%})")
#
# NameError: name 'test_failures' is not defined

# %%
# =============================================================================
# STEP 9: SAVE
# =============================================================================
print("\n" + "=" * 80)
print("💾 STEP 9: Saving model...")
print("=" * 80)
# Out:
# ================================================================================
# 💾 STEP 9: Saving model...
# ================================================================================

# %%
torch.save(model.state_dict(), "lstm_pytorch_model.pt")
print("   ✓ lstm_pytorch_model.pt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 torch.save(model.state_dict(), "lstm_pytorch_model.pt")
#       2 print("   ✓ lstm_pytorch_model.pt")
#
# NameError: name 'torch' is not defined

# %%
import joblib
joblib.dump(scaler, "lstm_scaler.pkl")
joblib.dump(feature_cols, "lstm_features.pkl")
joblib.dump(CONFIG, "lstm_config.pkl")
print("   ✓ Saved scaler, features, config")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 2
#       1 import joblib
# ----> 2 joblib.dump(scaler, "lstm_scaler.pkl")
#       3 joblib.dump(feature_cols, "lstm_features.pkl")
#       4 joblib.dump(CONFIG, "lstm_config.pkl")
#
# NameError: name 'scaler' is not defined

# %%
# =============================================================================
# FINAL SUMMARY
# =============================================================================
print("\n" + "=" * 80)
print("🏆 PYTORCH LSTM COMPLETE!")
print("=" * 80)
# Out:
# ================================================================================
# 🏆 PYTORCH LSTM COMPLETE!
# ================================================================================

# %%
print(f"""
✅ TRUE DEEP LEARNING (PyTorch):

   • LSTM learns TEMPORAL patterns from sequences
   • BACKPROPAGATION self-corrects weights each batch
   • GRADIENT DESCENT optimizes automatically
   • NO Random Forest, NO decision trees
   
   How it self-corrects each batch:
   ─────────────────────────────────
   1. Forward pass → prediction
   2. Loss calculation → error
   3. loss.backward() → compute gradients
   4. optimizer.step() → UPDATE WEIGHTS ← LEARNING!
   ─────────────────────────────────

📊 RESULTS:
   Failure Recall: {failure_recall:.0%} ({caught}/{len(test_failures)})
   Dust Detection: {dust_recall:.0%} ({dust_caught}/{total_dust})

💰 ROI: ${caught * 200000:,} saved
""")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 18
#       1 print(f"""
#       2 ✅ TRUE DEEP LEARNING (PyTorch):
#       3
#       4    • LSTM learns TEMPORAL patterns from sequences
#       5    • BACKPROPAGATION self-corrects weights each batch
#       6    • GRADIENT DESCENT optimizes automatically
#       7    • NO Random Forest, NO decision trees
#       8
#       9    How it self-corrects each batch:
#      10    ─────────────────────────────────
#      11    1. Forward pass → prediction
#      12    2. Loss calculation → error
#      13    3. loss.backward() → compute gradients
#      14    4. optimizer.step() → UPDATE WEIGHTS ← LEARNING!
#      15    ─────────────────────────────────
#      16
#      17 📊 RESULTS:
# ---> 18    Failure Recall: {failure_recall:.0%} ({caught}/{len(test_failures)})
#      19    Dust Detection: {dust_recall:.0%} ({dust_caught}/{total_dust})
#      20
#      21 💰 ROI: ${caught * 200000:,} saved
#      22 """)
#
# NameError: name 'failure_recall' is not defined

# %%
print("⏰ Done:", datetime.now().strftime("%H:%M:%S"))
# Out:
# ⏰ Done: 06:35:34
